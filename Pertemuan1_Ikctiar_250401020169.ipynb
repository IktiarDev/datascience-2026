# %% [markdown]
# # Identitas Penulis
# - **Nama Lengkap**: Muhammad Ikctiar Saputra
# - **NIM**: 250401020169
# - **Kelas**: IF401
# - **Program Studi**: PJJ Informatika

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
nama = "Muhammad Ikctiar Saputra"
nim = "250401020169"
kelas = "IF401"
prodi = "PJJ Informatika"
aktif = True

print(f"Nama     : {nama}")
print(f"NIM      : {nim}")
print(f"Kelas    : {kelas}")
print(f"Prodi    : {prodi}")
print(f"Aktif    : {aktif}")
# Out:
# Nama     : Muhammad Ikctiar Saputra
# NIM      : 250401020169
# Kelas    : IF401
# Prodi    : PJJ Informatika
# Aktif    : True

# %%
courses = ["Pengantar Data Science", "Struktur Data", "Basis Data", "Pemrograman Web"]

print("\nDaftar Mata Kuliah Semester Ini:")
for i, course in enumerate(courses, 1):
    print(f"{i}. {course}")
# Out:
# Daftar Mata Kuliah Semester Ini:
# 1. Pengantar Data Science
# 2. Struktur Data
# 3. Basis Data
# 4. Pemrograman Web

# %%
def perkenalan(nama, prodi, kelas):
    """Fungsi untuk menampilkan perkenalan mahasiswa dan tujuan belajar."""
    greeting = f"Hai! Saya {nama} dari prodi {prodi}, kelas {kelas}."
    tujuan = "Tujuan saya belajar Data Science adalah untuk menganalisis data perkuliahan secara otomatis."
    return f"{greeting}\n{tujuan}"

hasil = perkenalan(nama, prodi, kelas)
print(hasil)
# Out:
# Hai! Saya Muhammad Ikctiar Saputra dari prodi PJJ Informatika, kelas IF401.
# Tujuan saya belajar Data Science adalah untuk menganalisis data perkuliahan secara otomatis.

# %% [markdown]
# ## Kesimpulan
# Pada pertemuan pertama ini, saya telah mempelajari dasar-dasar pemrograman Python yang meliputi:
# 1. Penggunaan fungsi `print()` untuk menampilkan output ke layar console.
# 2. Pendefinisian variabel dengan tipe data dasar seperti String, Integer, dan Boolean.
# 3. Penggunaan tipe data list dan loop `for` menggunakan bantuan `enumerate()` untuk mencetak elemen berurutan secara dinamis.
# 4. Pembuatan fungsi kustom dengan parameter input dan nilai kembalian (*return value*) untuk pembungkusan logika kode.
#
# **Temuan Utama**: Sintaks pemrograman Python sangat sederhana dan ekspresif, yang menjadikannya sangat populer dan efisien untuk analisis data sains.
#
# **Keterbatasan/Pertanyaan**: Bagaimana cara memuat file data tabular (seperti CSV) dan melakukan pengolahan yang lebih mendalam dengan Python?
